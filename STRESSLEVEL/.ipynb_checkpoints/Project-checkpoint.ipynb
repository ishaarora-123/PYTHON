# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Responses.csv',encoding='latin1')

# %%
df.head()
# Out:
#     What is your age group?  Gender  \
# 0                     1824  Female
# 1                     1824    Male
# 2                     1824    Male
# 3                     1824    Male
# 4                     1824  Female
#
#   Type of Hobbies you engage in?(Select all that apply)  \
# 0                                   Creative, Social
# 1                               Intellectual, Others
# 2                     Physical, Intellectual, Social
# 3                  Creative, Physical, Intellectual
# 4                                          Physical
#
#   How often do you engage in your hobbies?    \
# 0                       Several times a week
# 1                       Several times a week
# 2                                     Weekly
# 3                                      Daily
# 4                            Less frequently
#
#   On average, how many hours per week do you spend on your hobbies?    \
# 0                                          13 hours
# ...

# %%
df['Number of hobbies'] = len(str(df['Type of Hobbies you engage in?(Select all that apply)']).split(','))

# %%
print(df.head())
# Out:
#     What is your age group?  Gender  \
# 0                     1824  Female
# 1                     1824    Male
# 2                     1824    Male
# 3                     1824    Male
# 4                     1824  Female
#
#   Type of Hobbies you engage in?(Select all that apply)  \
# 0                                   Creative, Social
# 1                               Intellectual, Others
# 2                    Physica, Intellectual , Social
# 3  Creative (e.g., painting, writing, playing an ...
# 4             Physical (e.g., sports, dancing, yoga)
#
#   How often do you engage in your hobbies?    \
# 0                       Several times a week
# 1                       Several times a week
# 2                                     Weekly
# 3                                      Daily
# 4                            Less frequently
#
#   On average, how many hours per week do you spend on your hobbies?    \
# 0                                          13 hours
# ...

# %%
df.head()
# Out:
#     What is your age group?  Gender  \
# 0                     1824  Female
# 1                     1824    Male
# 2                     1824    Male
# 3                     1824    Male
# 4                     1824  Female
#
#   Type of Hobbies you engage in?(Select all that apply)  \
# 0                                   Creative, Social
# 1                               Intellectual, Others
# 2                     Physical, Intellectual, Social
# 3                  Creative, Physical, Intellectual
# 4                                          Physical
#
#   How often do you engage in your hobbies?    \
# 0                       Several times a week
# 1                       Several times a week
# 2                                     Weekly
# 3                                      Daily
# 4                            Less frequently
#
#   On average, how many hours per week do you spend on your hobbies?    \
# 0                                          13 hours
# ...
